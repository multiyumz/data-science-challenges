# %% [markdown]
# # Your First Neural Network

# %% [markdown]
# 🎯 Goals of this challenge:
# - Writing the architecture of a Neural Network
# - Inspect some of the most important hyperparameters of a Neural Network

# %% [markdown]
# 🌗 In this challenge, we will be working with the **moons dataset**.
# * Your goal is to build a Neural Network which separates two classes.
# * Each data point $X$ has two coordinates $X = (x_1, x_2)$ and belongs to either the class 0 or the class 1
# * These bi-dimensional points can be represented on a 2D-scatterplot, using colors to represent to two available classes $\color{blue}{blue}$ and $\color{red}{red} $
# * Here is an example of such a moon dataset:
#
# <img src="https://wagon-public-datasets.s3.amazonaws.com/data-science-images/DL/moons_dataset.png" />

# %% [markdown]
# ## (1)  Generating the Moons dataset

# %% [markdown]
# 📚 Here, we will use the Scikit-Learn `make_moons` function [(see documentation here)](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html) to create 2 moons that cannot be linearly separated.
#
# 👉 Each moon corresponds to a class.

# %%
from sklearn.datasets import make_moons

### Generating the moons dataset
X, y = make_moons(n_samples=300, noise=0.25, random_state=0)

# %%
### This function allows to plot the two moons

import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

def plot_moons(X, y):
    df = pd.DataFrame(dict(x1=X[:,0], x2=X[:,1], label=y))
    colors = {0:'red', 1:'blue'}
    fig, ax = plt.subplots()
    grouped = df.groupby('label')

    for key, group in grouped:
        group.plot(ax=ax, kind='scatter', x='x1', y='x2', label=key, color=colors[key])
        
    
    plt.title(f"{len(X)} moons")
    plt.show()

plot_moons(X, y)

# %% [markdown]
# ❓  Play with the number of samples and the noise to discover the effects on the `moons dataset` ❓
#
# 🎨 Plot the moons for different values.

# %%
import numpy as np

# %%
moons = [100,200,300,400,500,600,700]

for moon in moons:
    X, y = make_moons(n_samples=moon, noise=0.9, random_state=0)
    plot_moons(X,y)

# %% [markdown]
# ❓ Create 250 samples of the data with ❓
# * a noise equal to 0.20
# * a random state equal to 0 to get the same results every time you re-run the notebook
# * and split the initial dataset into a train and test set (size: 70/30%)
#
# *Remark* : Please call the variables `X_train`, `y_train`, `X_test` and `y_test`

# %%
X, y = make_moons(n_samples=250, noise=0.2, random_state=0)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 0)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((175, 2), (75, 2), (175,), (75,))

# %% [markdown]
# ## (2) Designing a basic Neural Network  for a binary classification task

# %% [markdown]
# 🧠 You will now define your first neural network.
# The architecture of your model should have:
# - a first layer with:
#     - 5 neurons
#     - a _relu_ activation function
#     - the correct input dimension
# - an output layer suited to your binary classification task.
#
#
# ❓ Complete the next function with the previous architecture ❓

# %%
from tensorflow.keras import models, layers

# %%
def initialize_model():
    
    #############################
    #  1 - Model architecture   #
    #############################    
    model = models.Sequential()
    model.add(layers.Dense(5, input_dim=2, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
        
    #############################
    #  2 - Optimization Method  #
    #############################
    model.compile(loss='binary_crossentropy', # We've already mentioned this loss function in Logistic Regression
                  optimizer='adam', # Optimizer in Deep Learning = solver in Machine Learning | Adam = our best friend
                  metrics=['accuracy']) # Let's focus on the accuracy, our dataset is balanced
    
    return model

model = initialize_model()

# %% [markdown]
# ---
#
# <details>
#     <summary><i>Intuitions about the optimization method</i></summary>
#
# We'll keep this message short as you have a full course 📆 **Deep Learning - Optimizers, Loss, Fitting** coming soon.
#
# So, briefly speaking:
#
# - the ***.compile()*** tells your algorithm how to optimize the weights of your network when fitting the network on real data
#     - the ***binary_crossentropy*** is the "log-loss" that you have already seen in Machine Learning in the context of a Logistic Regression for classification
#     - To date, the ***adam*** optimizer is the gold standard in Deep Learning - an optimizer in Deep Learning is like a solver in Machine Learning: it provides an iterative method to minimize the loss function of an algorithm with respect to its parameters
#
# </details>
#
# ---

# %% [markdown]
# ❓ How many parameters does the model have?  ❓
#
# <details>
#     <summary><i>Hint</i></summary>
#
# The `.summary()`method displays:
#    - the stack of layers of your Neural Network
#    - the output shape after each layer
#    - the number of parameters for each layer (and consequently the total number of parameters)
#
# </details>

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_4 (Dense)             (None, 5)                 15
#
#  dense_5 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 21
# Trainable params: 21
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## (3) Training your Neural Network

# %% [markdown]
# ❓You are now ready to train your algorithm.
#
# Let's go! Initialize your model and fit it on the training set!
#
# Store the results of the training into a `history` variable. ❓

# %%
model = initialize_model()

# %%
history = model.fit(X_train, y_train, epochs=100, batch_size = 8, verbose=1)
# Out:
# Epoch 1/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7990 - accuracy: 0.4800
# Epoch 2/100
# 22/22 [==============================] - 0s 859us/step - loss: 0.7747 - accuracy: 0.4800
# Epoch 3/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7527 - accuracy: 0.4800
# Epoch 4/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7310 - accuracy: 0.4571
# Epoch 5/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7111 - accuracy: 0.4400
# Epoch 6/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6907 - accuracy: 0.4343
# Epoch 7/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6721 - accuracy: 0.4914
# Epoch 8/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6538 - accuracy: 0.5314
# Epoch 9/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6363 - accuracy: 0.6057
# Epoch 10/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6191 - accuracy: 0.6686
# Epoch 11/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6021 - accuracy: 0.7029
# Epoch 12/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5850 - accuracy: 0.7371
# Epoch 13/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5689 - accuracy: 0.7543
# Epoch 14/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.5535 - accuracy: 0.7714
# Epoch 15/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5390 - accuracy: 0.7886
# Epoch 16/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5250 - accuracy: 0.8114
# Epoch 17/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.5118 - accuracy: 0.8171
# Epoch 18/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4996 - accuracy: 0.8229
# Epoch 19/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4876 - accuracy: 0.8343
# Epoch 20/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4764 - accuracy: 0.8343
# Epoch 21/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4657 - accuracy: 0.8343
# Epoch 22/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4559 - accuracy: 0.8343
# Epoch 23/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4464 - accuracy: 0.8400
# Epoch 24/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4381 - accuracy: 0.8400
# Epoch 25/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4296 - accuracy: 0.8400
# Epoch 26/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4219 - accuracy: 0.8400
# Epoch 27/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4145 - accuracy: 0.8286
# Epoch 28/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4076 - accuracy: 0.8286
# Epoch 29/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4014 - accuracy: 0.8286
# Epoch 30/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3953 - accuracy: 0.8286
# Epoch 31/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3898 - accuracy: 0.8286
# Epoch 32/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3846 - accuracy: 0.8286
# Epoch 33/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3797 - accuracy: 0.8343
# Epoch 34/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3750 - accuracy: 0.8343
# Epoch 35/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3709 - accuracy: 0.8286
# Epoch 36/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3667 - accuracy: 0.8343
# Epoch 37/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3631 - accuracy: 0.8343
# Epoch 38/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3599 - accuracy: 0.8343
# Epoch 39/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.3562 - accuracy: 0.8343
# Epoch 40/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3531 - accuracy: 0.8343
# Epoch 41/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3503 - accuracy: 0.8343
# Epoch 42/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3475 - accuracy: 0.8343
# Epoch 43/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3449 - accuracy: 0.8343
# Epoch 44/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3425 - accuracy: 0.8400
# Epoch 45/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3402 - accuracy: 0.8400
# Epoch 46/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3381 - accuracy: 0.8400
# Epoch 47/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3360 - accuracy: 0.8400
# Epoch 48/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3343 - accuracy: 0.8400
# Epoch 49/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3322 - accuracy: 0.8400
# Epoch 50/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.3305 - accuracy: 0.8400
# Epoch 51/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3288 - accuracy: 0.8400
# Epoch 52/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3271 - accuracy: 0.8400
# Epoch 53/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3256 - accuracy: 0.8400
# Epoch 54/100
# 22/22 [==============================] - 0s 2ms/step - loss: 0.3244 - accuracy: 0.8400
# Epoch 55/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3230 - accuracy: 0.8400
# Epoch 56/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3216 - accuracy: 0.8400
# Epoch 57/100
# 22/22 [==============================] - 0s 997us/step - loss: 0.3205 - accuracy: 0.8400
# Epoch 58/100
# 22/22 [==============================] - 0s 1ms/step - loss: 0.

#   0.845714271068573,
#   0.845714271068573,
#   0.845714271068573,
#   0.845714271068573,
#   0.845714271068573,
#   0.845714271068573,
#   0.8514285683631897,
#   0.845714271068573,
#   0.8514285683631897,
#   0.8571428656578064,
#   0.8514285683631897,
#   0.8571428656578064,
#   0.8514285683631897,
#   0.8514285683631897,
#   0.8571428656578064,
#   0.8571428656578064,
#   0.8571428656578064,
#   0.8571428656578064,
#   0.8571428656578064]}

# %% [markdown]
# ❓ Plot the history of the train loss using the following function ❓

# %%
def plot_history(history):
    plt.plot(history.history['loss'])
    plt.title('Train loss')
    plt.ylabel('Loss')
    plt.xlabel('Epoch')
    plt.show()

# %%
plot_history(history)

# %% [markdown]
# ❓ What do you observe ❓

# %% [markdown]
# > YOUR ANSWER HERE

# %% [markdown]
# ❗️ <u>Evaluation on unseen data</u> ❗️
#
# 🧑🏻‍🏫 A Deep Learning Model is like any other Machine Learning model. Once you've trained it on the training set and are satisfied with how the Neural Network was able to learn, you need to ask: can it be generalized to unseen data such as the test set?

# %% [markdown]
# ## (4) Predict & Evaluate performance on test set

# %% [markdown]
# ❓ Predict the classes of the elements in the training set using _.predict()_ and store these predicted classes into a variable called `y_pred` ❓

# %%
y_pred = model.predict(X_test)
# Out:
# 3/3 [==============================] - 0s 1ms/step

# %% [markdown]
# ❓ What are your _loss_ and your _accuracy_ on the test set ❓
#
# 💡 In other words, you are asked to evaluate your Deep Learning model!

# %%
res = model.evaluate(X_test, y_test, verbose=0)

res
# Out:
# [0.2919061481952667, 0.8266666531562805]

# %%
loss = res[0]
accuracy = res[1]

# %% [markdown]
# **🧪 Test your code**

# %%
from nbresult import ChallengeResult
result = ChallengeResult('first_model', accuracy=accuracy)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /Users/bingobango/.pyenv/versions/tom/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/bingobango/code/lewagon/data-your-first-neural-network/tests
# plugins: anyio-3.6.1, asyncio-0.19.0, typeguard-2.13.3
# asyncio: mode=strict
# collecting ... collected 1 item
#
# test_first_model.py::TestFirstModel::test_accuracy PASSED                [100%]
#
# ============================== 1 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/first_model.pickle
#
# git commit -m 'Completed first_model step'
#
# git push origin master

# %% [markdown]
# ❓ Check the accuracy of your predictions visually by using our `plot_decision_regions` available in `utils/plots.py` ❓

# %%
from utils.plots import plot_decision_regions

# %%
plot_decision_regions(X,y,model)
# Out:
# 1940/1940 [==============================] - 1s 581us/step

# %% [markdown]
# 😥 It looks like we are **underfitting** a bit, right?
#
# 😁 We can try :
# - to train the model a bit longer...
# - ...or maybe to create a Deeper Neural network in the next section!

# %% [markdown]
# ## (5) Training your Neural Network with more epochs

# %% [markdown]
# ❓ Re-train the model for 500 iterations ❓
# - Don't forget to call the `initialize_model` function, otherwise, your initial parameters will be those you have already learned on the previous _.fit()_ ...!)
# - Plot the history to see how the loss changed over the different epochs/iterations.

# %%
model = initialize_model()

# %%
history = model.fit(X_train, y_train, epochs=500, batch_size = 8, verbose=1)
# Out:
# Epoch 1/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.8522 - accuracy: 0.4229
# Epoch 2/500
# 22/22 [==============================] - 0s 938us/step - loss: 0.8238 - accuracy: 0.5029
# Epoch 3/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.8015 - accuracy: 0.5200
# Epoch 4/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7806 - accuracy: 0.5257
# Epoch 5/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7632 - accuracy: 0.5257
# Epoch 6/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7470 - accuracy: 0.5257
# Epoch 7/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7316 - accuracy: 0.5314
# Epoch 8/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7167 - accuracy: 0.5543
# Epoch 9/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.7025 - accuracy: 0.5486
# Epoch 10/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6887 - accuracy: 0.5486
# Epoch 11/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6745 - accuracy: 0.5486
# Epoch 12/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6610 - accuracy: 0.5600
# Epoch 13/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6481 - accuracy: 0.5543
# Epoch 14/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6357 - accuracy: 0.5486
# Epoch 15/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6238 - accuracy: 0.5371
# Epoch 16/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.6125 - accuracy: 0.5143
# Epoch 17/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.6022 - accuracy: 0.5314
# Epoch 18/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.5920 - accuracy: 0.5657
# Epoch 19/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.5831 - accuracy: 0.6114
# Epoch 20/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5743 - accuracy: 0.6971
# Epoch 21/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5661 - accuracy: 0.7543
# Epoch 22/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5585 - accuracy: 0.7829
# Epoch 23/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5515 - accuracy: 0.7943
# Epoch 24/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.5446 - accuracy: 0.8000
# Epoch 25/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.5386 - accuracy: 0.8057
# Epoch 26/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5323 - accuracy: 0.8114
# Epoch 27/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5266 - accuracy: 0.8114
# Epoch 28/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5215 - accuracy: 0.8114
# Epoch 29/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5163 - accuracy: 0.8114
# Epoch 30/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5116 - accuracy: 0.8171
# Epoch 31/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5066 - accuracy: 0.8229
# Epoch 32/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.5024 - accuracy: 0.8229
# Epoch 33/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4980 - accuracy: 0.8229
# Epoch 34/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4941 - accuracy: 0.8229
# Epoch 35/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4903 - accuracy: 0.8229
# Epoch 36/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4863 - accuracy: 0.8229
# Epoch 37/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4826 - accuracy: 0.8229
# Epoch 38/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4787 - accuracy: 0.8229
# Epoch 39/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4751 - accuracy: 0.8229
# Epoch 40/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4712 - accuracy: 0.8229
# Epoch 41/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4676 - accuracy: 0.8229
# Epoch 42/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4637 - accuracy: 0.8343
# Epoch 43/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4598 - accuracy: 0.8343
# Epoch 44/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4560 - accuracy: 0.8343
# Epoch 45/500
# 22/22 [==============================] - 0s 3ms/step - loss: 0.4522 - accuracy: 0.8400
# Epoch 46/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4485 - accuracy: 0.8400
# Epoch 47/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4446 - accuracy: 0.8400
# Epoch 48/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4410 - accuracy: 0.8400
# Epoch 49/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4375 - accuracy: 0.8400
# Epoch 50/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4338 - accuracy: 0.8400
# Epoch 51/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4300 - accuracy: 0.8400
# Epoch 52/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4265 - accuracy: 0.8400
# Epoch 53/500
# 22/22 [==============================] - 0s 2ms/step - loss: 0.4227 - accuracy: 0.8400
# Epoch 54/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4193 - accuracy: 0.8400
# Epoch 55/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4154 - accuracy: 0.8400
# Epoch 56/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4120 - accuracy: 0.8400
# Epoch 57/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4086 - accuracy: 0.8400
# Epoch 58/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4051 - accuracy: 0.8400
# Epoch 59/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.4017 - accuracy: 0.8400
# Epoch 60/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3985 - accuracy: 0.8400
# Epoch 61/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3950 - accuracy: 0.8400
# Epoch 62/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3919 - accuracy: 0.8400
# Epoch 63/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3883 - accuracy: 0.8400
# Epoch 64/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3850 - accuracy: 0.8400
# Epoch 65/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3815 - accuracy: 0.8400
# Epoch 66/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3785 - accuracy: 0.8400
# Epoch 67/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3749 - accuracy: 0.8400
# Epoch 68/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3715 - accuracy: 0.8400
# Epoch 69/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3683 - accuracy: 0.8400
# Epoch 70/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3650 - accuracy: 0.8400
# Epoch 71/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3616 - accuracy: 0.8400
# Epoch 72/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3583 - accuracy: 0.8400
# Epoch 73/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3550 - accuracy: 0.8400
# Epoch 74/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3518 - accuracy: 0.8400
# Epoch 75/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3487 - accuracy: 0.8400
# Epoch 76/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3459 - accuracy: 0.8400
# Epoch 77/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3431 - accuracy: 0.8400
# Epoch 78/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3400 - accuracy: 0.8400
# Epoch 79/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3374 - accuracy: 0.8400
# Epoch 80/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3348 - accuracy: 0.8400
# Epoch 81/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3322 - accuracy: 0.8400
# Epoch 82/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3298 - accuracy: 0.8400
# Epoch 83/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3274 - accuracy: 0.8400
# Epoch 84/500
# 22/22 [==============================] - 0s 970us/step - loss: 0.3253 - accuracy: 0.8400
# Epoch 85/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3232 - accuracy: 0.8400
# Epoch 86/500
# 22/22 [==============================] - 0s 910us/step - loss: 0.3212 - accuracy: 0.8400
# Epoch 87/500
# 22/22 [==============================] - 0s 1ms/step - loss: 0.3190 - accuracy: 0.
# 22/22 [==============================] - 0s 862us/step - loss: 0.2245 - accuracy: 0.9143
# Epoch 500/500
# 22/22 [==============================] - 0s 856us/step - loss: 0.2249 - accuracy: 0.9143

# %%
plot_history(history)

# %% [markdown]
# ❓ Did the test accuracy improve? ❓

# %%
res = model.evaluate(X_test, y_test, verbose=0)
res
# Out:
# [0.26912128925323486, 0.8533333539962769]

# %% [markdown]
# <details>
#     <summary><i>Not really... explanations here</i></summary>
#
# * The accuracy did not increase by training the model with more epochs...
# * So when should have we stopped the training of this Deep Learning Model?
#     * Answer in the next chapter <b><i>Deep Learning - Optimizers, Loss and Fitting</i></b>
#
# </details>

# %% [markdown]
# ## (6) A Deeper Deep Learning Model

# %% [markdown]
# ❓ Let's try a **deeper** architecture that includes the following layers:
#
# - a first layer with 20 neurons (activation: `"relu"`)
# - a second layer with 10 neurons (activation: `"relu"`)
# - a third layer with 5 neurons (activation: `"relu"`)
# - an output layer suitable for this problem ❓

# %%
def initialize_model_2():
    
    #############################
    #  1 - Model architecture   #
    #############################   
    
    model = models.Sequential()
    
    model.add(layers.Dense(20, input_dim=2, activation='relu'))
    model.add(layers.Dense(10, activation='relu'))
    model.add(layers.Dense(5, activation='relu'))
    model.add(layers.Dense(1, activation='sigmoid'))
    
    #############################
    #  2 - Optimization Method  #
    #############################
    model.compile(loss='binary_crossentropy', # We've already mentioned this loss function in Logistic Regression
                  optimizer='adam', # Optimizer in Deep Learning = solver in Machine Learning | Adam = our best friend
                  metrics=['accuracy']) # Let's focus on the accuracy, our dataset is balanced
    
    return model

# %%
model = initialize_model_2()

# %% [markdown]
# ❓ What is the number of parameters of your new model ❓

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_22 (Dense)            (None, 20)                60
#
#  dense_23 (Dense)            (None, 10)                210
#
#  dense_24 (Dense)            (None, 5)                 55
#
#  dense_25 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 331
# Trainable params: 331
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ❓ Run your model on the previous dataset for 500 epochs and plot the loss afterwards ❓

# %%
model = initialize_model_2()

history = model.fit(
            X_train, y_train,
            epochs=500,
            batch_size=8,
            verbose=0)

# %%
plot_history(history)

# %% [markdown]
# ❓ What is your accuracy on the test test ? Store it as `accuracy_deep` variable (`float`) ❓

# %%
res = model.evaluate(X_test, y_test)
res[1]
# Out:
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3558 - accuracy: 0.9200
# 0.9200000166893005

# %%
accuracy_deep = res[1]

# %% [markdown]
# 🧪 **Test your code**

# %%
from nbresult import ChallengeResult
result = ChallengeResult('deeper_model',
                         accuracy=accuracy_deep)
result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.10.6, pytest-7.1.3, pluggy-1.0.0 -- /Users/bingobango/.pyenv/versions/tom/bin/python3
# cachedir: .pytest_cache
# rootdir: /Users/bingobango/code/lewagon/data-your-first-neural-network/tests
# plugins: anyio-3.6.1, asyncio-0.19.0, typeguard-2.13.3
# asyncio: mode=strict
# collecting ... collected 1 item
#
# test_deeper_model.py::TestDeeperModel::test_accuracy PASSED              [100%]
#
# ============================== 1 passed in 0.01s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/deeper_model.pickle
#
# git commit -m 'Completed deeper_model step'
#
# git push origin master

# %% [markdown]
# ❓ Do you think we are overfitting on the noise ❓ Once again, use the `plot_decision_regions` function to help your intuition.

# %%
plot_decision_regions(X,y,model)
# Out:
# 1940/1940 [==============================] - 1s 582us/step

# %% [markdown]
# ---
#
# 🏁 Congratulations!
#
# 💾 Don't forget to `git add/commit/push` your notebook...
#
# 🚀 ... and move on to the next challenge!
