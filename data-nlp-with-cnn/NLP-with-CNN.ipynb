# %% [markdown]
# # NLP with CNN
#
# ### Exercise objectives:
#
# - Use CNN instead of RNN for NLP
#
# <hr>
# <hr>
#
#
# # The data
#
#
# ❓ **Question** ❓ Let's first load the data. You don't have to understand what is going on in the function, it does not matter here.
#
# ⚠️ **Warning** ⚠️ The `load_data` function has a `percentage_of_sentences` argument. Depending on your computer, there are chances that too many sentences will make your compute slow down, or even freeze - your RAM can overflow. For that reason, **you should start with 10% of the sentences** and see if your computer handles it. Otherwise, rerun with a lower number.
#
# ⚠️ **DISCLAIMER** ⚠️ **No need to play _who has the biggest_ (RAM) !** The idea is to get to run your models quickly to prototype. Even in real life, it is recommended that you start with a subset of your data to loop and debug quickly. So increase the number only if you are into getting the best accuracy.

# %%
######################################
### Run this cell to load the data ###
######################################

import tensorflow_datasets as tfds
from tensorflow.keras.preprocessing.text import text_to_word_sequence

def load_data(percentage_of_sentences=None):
    train_data, test_data = tfds.load(name="imdb_reviews", split=["train", "test"], batch_size=-1, as_supervised=True)

    train_sentences, y_train = tfds.as_numpy(train_data)
    test_sentences, y_test = tfds.as_numpy(test_data)
    
    # Take only a given percentage of the entire data
    if percentage_of_sentences is not None:
        assert(percentage_of_sentences> 0 and percentage_of_sentences<=100)
        
        len_train = int(percentage_of_sentences/100*len(train_sentences))
        train_sentences, y_train = train_sentences[:len_train], y_train[:len_train]
  
        len_test = int(percentage_of_sentences/100*len(test_sentences))
        test_sentences, y_test = test_sentences[:len_test], y_test[:len_test]
    
    X_train = [text_to_word_sequence(_.decode("utf-8")) for _ in train_sentences]
    X_test = [text_to_word_sequence(_.decode("utf-8")) for _ in test_sentences]
    
    return X_train, y_train, X_test, y_test

X_train, y_train, X_test, y_test = load_data(percentage_of_sentences=10)
# Out:
# 2022-11-17 10:31:21.250608: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-17 10:31:26.348554: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# Remember that to do NLP, you need to go through one of the following options, as shown here:
#
# <img src="embedding_or_RNN.png" width="700px" />
#
# But in both cases, you can replace the recurrent layer (top part) by a CNN layer. We will go into both, starting from the one on the left were the embedding is learned in the network.
#
#
#
#
# # Part 1 : Concatenate a Keras Embedding with a Conv1D🔥
#
# Let's train a fancy network here.
#
# Each of your words is represented by a vector of size N (the size of your embedding). Therefore, as a sentence is a sequence of words, it is represented by a matrix (number of words, N). So, all your sentences are actually represented as matrices once embedded.
#
# If you think about it, an image is also a matrix. Said differently, you may represent your sentence of word as a matrix, where each column (or row, depending on how you want to look at it) is a word, and each row (or each column) corresponds to a coordinate in the embedding space. As shown here
#
# <img src="image_comparison.png" width="500px" />
#
# Well, in that case, as these are close to images, why not using convolution on them? Yes, convolutions!
# But, be careful. In the case of images, convolutions are 2 dimensional as the filters can move up and down, and left and right. In the case of our sentences, we want the kernel to move _only_ in the word by word direction (The alternative, moving coordinate by coordinate of the embedding space doesn't make much sense).
#
# So let's create a model that use convolutions.

# %% [markdown]
# ## First, the data
#
# ❓ **Question** ❓ You will need to prepare your data. First, tokenize them. Then, you need to pad them (use a value `maxlen` equal to 150). You also might need to compute the size of your vocabulary ;)

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

X_train_token = tokenizer.texts_to_sequences(X_train)
X_test_token = tokenizer.texts_to_sequences(X_test)

X_train_pad = pad_sequences(X_train_token, maxlen=150, dtype='float32')
X_test_pad = pad_sequences(X_test_token, maxlen=150, dtype='float32')


vocab_size = len(tokenizer.word_index)

# %%
vocab_size
# Out:
# 30419

# %%
tokenizer.word_index
# Out:
# {'the': 1,
#  'a': 2,
#  'and': 3,
#  'of': 4,
#  'to': 5,
#  'is': 6,
#  'br': 7,
#  'in': 8,
#  'i': 9,
#  'it': 10,
#  'this': 11,
#  'that': 12,
#  'was': 13,
#  'as': 14,
#  'for': 15,
#  'with': 16,
#  'but': 17,
#  'movie': 18,
#  'film': 19,
#  'on': 20,
#  'not': 21,
#  'you': 22,
#  'his': 23,
#  'are': 24,
#  'have': 25,
#  'one': 26,
#  'be': 27,
#  'he': 28,
#  'all': 29,
#  'at': 30,
#  'by': 31,
#  'they': 32,
#  'an': 33,
#  'so': 34,
#  'like': 35,
#  'who': 36,
#  'from': 37,
#  'her': 38,
#  'or': 39,
#  'just': 40,
#  'if': 41,
#  'out': 42,
#  'about': 43,
#  "it's": 44,
#  'has': 45,
#  'what': 46,
#  'some': 47,
#  'there': 48,
#  'good': 49,
#  'more': 50,
#  'when': 51,
#  'very': 52,
#  'no': 53,
#  'up': 54,
#  'she': 55,
#  'my': 56,
#  'time': 57,
#  'even': 58,
#  'which': 59,
#  'would': 60,
#  'really': 61,
#  'only': 62,
#  'had': 63,
#  'story': 64,
#  'me': 65,
#  'see': 66,
#  'can': 67,
#  'their': 68,
#  'were': 69,
#  'well': 70,
#  'than': 71,
#  'much': 72,
#  'get': 73,
#  'do': 74,
#  'great': 75,
#  'been': 76,
#  'we': 77,
#  'first': 78,
#  'bad': 79,
#  'because': 80,
#  'into': 81,
#  'other': 82,
#  'will': 83,
#  'how': 84,
#  'also': 85,
#  'most': 86,
#  'then': 87,
#  'too': 88,
#  'him': 89,
#  'made': 90,
#  "don't": 91,
#  'people': 92,
#  'way': 93,
#  'them': 94,
#  'make': 95,
#  'its': 96,
#  'movies': 97,
#  'could': 98,
#  'any': 99,
#  'films': 100,
#  'think': 101,
#  'watch': 102,
#  'plot': 103,
#  'after': 104,
#  'two': 105,
#  'best': 106,
#  'many': 107,
#  'acting': 108,
#  'life': 109,
#  'character': 110,
#  'characters': 111,
#  'never': 112,
#  'seen': 113,
#  'where': 114,
#  'being': 115,
#  'did': 116,
#  'over': 117,
#  'little': 118,
#  'these': 119,
#  'love': 120,
#  'end': 121,
#  'man': 122,
#  'show': 123,
#  'better': 124,
#  'off': 125,
#  'ever': 126,
#  'know': 127,
#  'still': 128,
#  'does': 129,
#  'say': 130,
#  'while': 131,
#  'your': 132,
#  'scene': 133,
#  'go': 134,
#  'why': 135,
#  'should': 136,
#  'through': 137,
#  'such': 138,
#  'here': 139,
#  'scenes': 140,
#  'something': 141,
#  'real': 142,
#  'back': 143,
#  'now': 144,
#  'thing': 145,
#  "i'm": 146,
#  "doesn't": 147,
#  'find': 148,
#  'before': 149,
#  "didn't": 150,
#  'though': 151,
#  'makes': 152,
#  'old': 153,
#  'again': 154,
#  'watching': 155,
#  'funny': 156,
#  'new': 157,
#  'those': 158,
#  'every': 159,
#  'director': 160,
#  'actors': 161,
#  'years': 162,
#  'going': 163,
#  'nothing': 164,
#  'actually': 165,
#  'another': 166,
#  'look': 167,
#  'same': 168,
#  'work': 169,
#  'part': 170,
#  '10': 171,
#  'pretty': 172,
#  'want': 173,
#  'quite': 174,
#  'few': 175,
#  'young': 176,
#  'thought': 177,
#  'down': 178,
#  'bit': 179,
#  'horror': 180,
#  'own': 181,
#  'cast': 182,
#  "can't": 183,
#  'give': 184,
#  'around': 185,
#  'fact': 186,
#  'lot': 187,
#  "that's": 188,
#  'world': 189,
#  'things': 190,
#  'enough': 191,
#  'point': 192,
#  'series': 193,
#  'both': 194,
#  'may': 195,
#  'done': 196,
#  'long': 197,
#  'seems': 198,
#  'got': 199,
#  'however': 200,
#  'gets': 201,
#  'take': 202,
#  'role': 203,
#  'us': 204,
#  'always': 205,
#  'original': 206,
#  'between': 207,
#  'big': 208,
#  'right': 209,
#  'saw': 210,
#  'music': 211,
#  'times': 212,
#  'without': 213,
#  "i've": 214,
#  "isn't": 215,
#  'family': 216,
#  'far': 217,
#  'whole': 218,
#  'might': 219,
#  'minutes': 220,
#  'am': 221,
#  'come': 222,
#  'least': 223,
#  "there's": 224,
#  '2': 225,
#  'action': 226,
#  'script': 227,
#  'must': 228,
#  'tv': 229,
#  'since': 230,
#  'kind': 231,
#  'away': 232,
#  'interesting': 233,
#  'almost': 234,
#  'guy': 235,
#  'fun': 236,
#  'performance': 237,
#  'rather': 238,
#  'especially': 239,
#  'anything': 240,
#  'hard': 241,
#  'last': 242,
#  'actor': 243,
#  'sure': 244,
#  'believe': 245,
#  'three': 246,
#  'girl': 247,
#  'comedy': 248,
#  "he's": 249,
#  'ending': 250,
#  'making': 251,
#  'worst': 252,
#  'looking': 253,
#  'anyone': 254,
#  'woman': 255,
#  'screen': 256,
#  'day': 257,
#  'trying': 258,
#  'maybe': 259,
#  'found': 260,
#  'course': 261,
#  'watched': 262,
#  'each': 263,
#  'having': 264,
#  'set': 265,
#  'probably': 266,
#  'yet': 267,
#  'although': 268,
#  'book': 269,
#  'comes': 270,
#  'feel': 271,
#  'money': 272,
#  'everything': 273,
#  'played': 274,
#  "wasn't": 275,
#  'night': 276,
#  'true': 277,
#  'goes': 278,
#  'instead': 279,
#  'put': 280,
#  'sense': 281,
#  'reason': 282,
#  'place': 283,
#  'high': 284,
#  'dvd': 285,
#  'audience': 286,
#  'main': 287,
#  'looks': 288,
#  'later': 289,
#  '1': 290,
#  'different': 291,
#  'job': 292,
#  'second': 293,
#  'once': 294,
#  'shows': 295,
#  'during': 296,
#  'american': 297,
#  'else': 298,
#  'together': 299,
#  'takes': 300,
#  'worth': 301,
#  'someone': 302,
#  'plays': 303,
#  'fan': 304,
#  'wife': 305,
#  'our': 306,
#  'said': 307,
#  'play': 308,
#  'star': 309,
#  'year': 310,
#  'read': 311,
#  'effects': 312,
#  'version': 313,
#  'home': 314,
#  'special': 315,
#  'half': 316,
#  'black': 317,
#  'idea': 318,
#  'boring': 319,
#  'seeing': 320,
#  'given': 321,
#  'help': 322,
#  '3': 323,
#  'less': 324,
#  'war': 325,
#  'beautiful': 326,
#  'house': 327,
#  'seem': 328,
#  'himself': 329,
#  'death': 330,
#  "you're": 331,
#  'production': 332,
#  'left': 333,
#  'mind': 334,
#  'excellent': 335,
#  'simply': 336,
#  'john': 337,
#  'top': 338,
#  'either': 339,
#  'short': 340,
#  'camera': 341,
#  'hollywood': 342,
#  'stupid': 343,
#  'poor': 344,
#  'shot': 345,
#  'couple': 346,
#  'father': 347,
#  'used': 348,
#  'perfect': 349,
#  'line': 350,
#  'dead': 351,
#  'until': 352,
#  'nice': 353,
#  "couldn't": 354,
#  'kids': 355,
#  'understand': 356,
#  'try': 357,
#  'enjoy': 358,
#  'classic': 359,
#  'completely': 360,
#  'mean': 361,
#  'along': 362,
#  'wrong': 363,
#  'awful': 364,
#  'rest': 365,
#  'perhaps': 366,
#  'everyone': 367,
#  'start': 368,
#  'need': 369,
#  'performances': 370,
#  'truly': 371,
#  'men': 372,
#  'boy': 373,
#  "i'd": 374,
#  'name': 375,
#  'finally': 376,
#  'liked': 377,
#  'budget': 378,
#  'keep': 379,
#  'small': 380,
#  'gives': 381,
#  'head': 382,
#  'felt': 383,
#  'wonderful': 384,
#  'full': 385,
#  'face': 386,
#  'style': 387,
#  '\x96': 388,
#  'early': 389,
#  'mr': 390,
#  'stars': 391,
#  'let': 392,
#  'low': 393,
#  'friends': 394,
#  'tell': 395,
#  'drama': 396,
#  'hope': 397,
#  'written': 398,
#  'school': 399,
#  'dialogue': 400,
#  'recommend': 401,
#  'terrible': 402,
#  'case': 403,
#  'worse': 404,
#  'based': 405,
#  'sort': 406,
#  'moments': 407,
#  'run': 408,
#  'playing': 409,
#  'next': 410,
#  'video': 411,
#  'supposed': 412,
#  'mother': 413,
#  'often': 414,
#  'getting': 415,
#  'yes': 416,
#  'become': 417,
#  'use': 418,
#  'loved': 419,
#  'human': 420,
#  'came': 421,
#  'absolutely': 422,
#  'others': 423,
#  'totally': 424,
#  'called': 425,
#  'lines': 426,
#  'fans': 427,
#  'certainly': 428,
#  'side': 429,
#  "they're": 430,
#  'days': 431,
#  'doing': 432,
#  'entertaining': 433,
#  'example': 434,
#  'dark': 435,
#  'overall': 436,
#  'live': 437,
#  'art': 438,
#  'killer': 439,
#  'definitely': 440,
#  'lost': 441,
#  'went': 442,
#  'seemed': 443,
#  'city': 444,
#  'beginning': 445,
#  'friend': 446,
#  'tries': 447,
#  'problem': 448,
#  'town': 449,
#  'picture': 450,
#  'turn': 451,
#  'god': 452,
#  'remember': 453,
#  'against': 454,
#  'evil': 455,
#  'entire': 456,
#  'care': 457,
#  'wanted': 458,
#  'already': 459,
#  'fine': 460,
#  'sex': 461,
#  'actress': 462,
#  'close': 463,
#  'women': 464,
#  'itself': 465,
#  'particularly': 466,
#  'title': 467,
#  'history': 468,
#  'act': 469,
#  'throughout': 470,
#  'writing': 471,
#  'myself': 472,
#  'episode': 473,
#  "won't": 474,
#  'white': 475,
#  'under': 476,
#  'cinema': 477,
#  'etc': 478,
#  'sound': 479,
#  "she's": 480,
#  'unfortunately': 481,
#  'anyway': 482,
#  'oh': 483,
#  'wants': 484,
#  'hand': 485,
#  'direction': 486,
#  'piece': 487,
#  'cannot': 488,
#  'daughter': 489,
#  'stuff': 490,
#  '5': 491,
#  'behind': 492,
#  'despite': 493,
#  'themselves': 494,
#  'humor': 495,
#  'lives': 496,
#  'children': 497,
#  'eyes': 498,
#  'lead': 499,
#  'highly': 500,
#  'able': 501,
#  'late': 502,
#  'moment': 503,
#  'hour': 504,
#  'person': 505,
#  'becomes': 506,
#  'kid': 507,
#  'waste': 508,
#  'child': 509,
#  'parts': 510,
#  'leave': 511,
#  'favorite': 512,
#  'viewer': 513,
#  'kill': 514,
#  'slow': 515,
#  'says': 516,
#  'thinking': 517,
#  "you'll": 518,
#  'guys': 519,
#  'murder': 520,
#  'soon': 521,
#  'decent': 522,
#  'age': 523,
#  'past': 524,
#  'expect': 525,
#  'girls': 526,
#  'type': 527,
#  'guess': 528,
#  'voice': 529,
#  '4': 530,
#  'happen': 531,
#  'brilliant': 532,
#  'b': 533,
#  'obvious': 534,
#  'matter': 535,
#  'several': 536,
#  'starts': 537,
#  'feeling': 538,
#  'michael': 539,
#  'heart': 540,
#  'final': 541,
#  'genre': 542,
#  'ok': 543,
#  'looked': 544,
#  'directed': 545,
#  'except': 546,
#  'involved': 547,
#  'flick': 548,
#  'police': 549,
#  'chance': 550,
#  'sometimes': 551,
#  'laugh': 552,
#  'blood': 553,
#  'opinion': 554,
#  'including': 555,
#  'experience': 556,
#  'number': 557,
#  'strong': 558,
#  'alone': 559,
#  'power': 560,
#  'gave': 561,
#  'robert': 562,
#  'attempt': 563,
#  'score': 564,
#  'works': 565,
#  'possible': 566,
#  'writer': 567,
#  'david': 568,
#  'told': 569,
#  'annoying': 570,
#  'somewhat': 571,
#  'known': 572,
#  "i'll": 573,
#  'wonder': 574,
#  'stop': 575,
#  'cut': 576,
#  "aren't": 577,
#  'episodes': 578,
#  'enjoyed': 579,
#  'killed': 580,
#  'took': 581,
#  'turned': 582,
#  'wish': 583,
#  'happens': 584,
#  'words': 585,
#  'turns': 586,
#  "film's": 587,
#  'amazing': 588,
#  'english': 589,
#  'happened': 590,
#  'today': 591,
#  'lady': 592,
#  'view': 593,
#  'whose': 594,
#  'sequel': 595,
#  'horrible': 596,
#  'hit': 597,
#  'ago': 598,
#  'jane': 599,
#  'simple': 600,
#  'female': 601,
#  'quality': 602,
#  'scary': 603,
#  'coming': 604,
#  'seriously': 605,
#  'mystery': 606,
#  'save': 607,
#  'james': 608,
#  'relationship': 609,
#  'group': 610,
#  'please': 611,
#  'roles': 612,
#  'novel': 613,
#  'single': 614,
#  's': 615,
#  'middle': 616,
#  'musical': 617,
#  'hell': 618,
#  'across': 619,
#  'word': 620,
#  "wouldn't": 621,
#  'level': 622,
#  'serious': 623,
#  'lack': 624,
#  'usually': 625,
#  'mostly': 626,
#  'shown': 627,
#  'eye': 628,
#  'king': 629,
#  'red': 630,
#  'sad': 631,
#  'crap': 632,
#  'bring': 633,
#  'york': 634,
#  'body': 635,
#  'running': 636,
#  'car': 637,
#  'jokes': 638,
#  'herself': 639,
#  'hours': 640,
#  'light': 641,
#  'self': 642,
#  'happy': 643,
#  '7': 644,
#  'gore': 645,
#  'events': 646,
#  'obviously': 647,
#  "'": 648,
#  'room': 649,
#  'basically': 650,
#  'british': 651,
#  'fight': 652,
#  'important': 653,
#  'miss': 654,
#  'comic': 655,
#  'cool': 656,
#  'son': 657,
#  'husband': 658,
#  'interest': 659,
#  'extremely': 660,
#  'documentary': 661,
#  'due': 662,
#  'local': 663,
#  'stories': 664,
#  'hilarious': 665,
#  'none': 666,
#  'predictable': 667,
#  'shots': 668,
#  'thriller': 669,
#  'started': 670,
#  'huge': 671,
#  'brother': 672,
#  'straight': 673,
#  'elements': 674,
#  'taken': 675,
#  'ten': 676,
#  'lame': 677,
#  'call': 678,
#  'dull': 679,
#  'oscar': 680,
#  'above': 681,
#  'yourself': 682,
#  'add': 683,
#  'richard': 684,
#  'near': 685,
#  'surprised': 686,
#  'rating': 687,
#  'released': 688,
#  'game': 689,
#  'clearly': 690,
#  'hero': 691,
#  'sets': 692,
#  'usual': 693,
#  'ridiculous': 694,
#  'storyline': 695,
#  'disappointed': 696,
#  'complete': 697,
#  'talent': 698,
#  'romantic': 699,
#  'entertainment': 700,
#  'country': 701,
#  'television': 702,
#  "let's": 703,
#  'lee': 704,
#  'fast': 705,
#  'supporting': 706,
#  'violence': 707,
#  'similar': 708,
#  'dialog': 709,
#  '9': 710,
#  'falls': 711,
#  'heard': 712,
#  'apparently': 713,
#  'finds': 714,
#  'japanese': 715,
#  'nor': 716,
#  'giving': 717,
#  'twist': 718,
#  'beyond': 719,
#  'attention': 720,
#  'ones': 721,
#  'whether': 722,
#  'editing': 723,
#  'songs': 724,
#  'tale': 725,
#  'song': 726,
#  'die': 727,
#  "haven't": 728,
#  'minute': 729,
#  'fall': 730,
#  'peter': 731,
#  'lots': 732,
#  'exactly': 733,
#  'figure': 734,
#  'saying': 735,
#  'taking': 736,
#  'moving': 737,
#  'possibly': 738,
#  'reality': 739,
#  'screenplay': 740,
#  'strange': 741,
#  'wait': 742,
#  'non': 743,
#  'jack': 744,
#  'typical': 745,
#  'comments': 746,
#  'stay': 747,
#  'means': 748,
#  'future': 749,
#  'realistic': 750,
#  'cinematography': 751,
#  'mention': 752,
#  'sit': 753,
#  'somehow': 754,
#  'sorry': 755,
#  'named': 756,
#  'animation': 757,
#  'indeed': 758,
#  'message': 759,
#  'talk': 760,
#  'living': 761,
#  'street': 762,
#  'modern': 763,
#  'rock': 764,
#  'ends': 765,
#  "who's": 766,
#  'class': 767,
#  'earth': 768,
#  'kept': 769,
#  'brought': 770,
#  'imagine': 771,
#  'major': 772,
#  'third': 773,
#  'nearly': 774,
#  'sequence': 775,
#  'atmosphere': 776,
#  'bunch': 777,
#  'theme': 778,
#  'reviews': 779,
#  'christmas': 780,
#  'whom': 781,
#  'expected': 782,
#  'fantastic': 783,
#  'hate': 784,
#  'opening': 785,
#  'easily': 786,
#  'check': 787,
#  'imdb': 788,
#  'doubt': 789,
#  'enjoyable': 790,
#  'tells': 791,
#  'baby': 792,
#  'appears': 793,
#  'sounds': 794,
#  'career': 795,
#  'laughs': 796,
#  'writers': 797,
#  'air': 798,
#  'nature': 799,
#  're': 800,
#  'cheap': 801,
#  'dream': 802,
#  'sadly': 803,
#  'easy': 804,
#  'emotional': 805,
#  'within': 806,
#  'talking': 807,
#  't': 808,
#  'ways': 809,
#  'knew': 810,
#  'begins': 811,
#  'four': 812,
#  'five': 813,
#  'effort': 814,
#  'viewers': 815,
#  'silly': 816,
#  'material': 817,
#  'comment': 818,
#  'knows': 819,
#  'meet': 820,
#  'stand': 821,
#  'parents': 822,
#  'difficult': 823,
#  'hot': 824,
#  'upon': 825,
#  'leads': 826,
#  'avoid': 827,
#  'points': 828,
#  'suspense': 829,
#  'french': 830,
#  'gone': 831,
#  'believable': 832,
#  'weird': 833,
#  'wasted': 834,
#  'review': 835,
#  'period': 836,
#  'dramatic': 837,
#  'season': 838,
#  'leading': 839,
#  'wrote': 840,
#  'books': 841,
#  'george': 842,
#  'order': 843,
#  'directors': 844,
#  "what's": 845,
#  'directing': 846,
#  'hear': 847,
#  'portrayed': 848,
#  'famous': 849,
#  'using': 850,
#  'casting': 851,
#  '8': 852,
#  'release': 853,
#  'working': 854,
#  'change': 855,
#  'problems': 856,
#  'among': 857,
#  'feels': 858,
#  'theater': 859,
#  'tried': 860,
#  'appear': 861,
#  'setting': 862,
#  'needs': 863,
#  'married': 864,
#  'deal': 865,
#  'sequences': 866,
#  'decided': 867,
#  'perfectly': 868,
#  'begin': 869,
#  'hair': 870,
#  'clear': 871,
#  'interested': 872,
#  "you've": 873,
#  'space': 874,
#  'return': 875,
#  'poorly': 876,
#  'depth': 877,
#  'western': 878,
#  'box': 879,
#  'odd': 880,
#  'follow': 881,
#  'social': 882,
#  'girlfriend': 883,
#  'meant': 884,
#  'particular': 885,
#  'premise': 886,
#  'otherwise': 887,
#  'forced': 888,
#  'shame': 889,
#  'potential': 890,
#  'de': 891,
#  'worked': 892,
#  'eventually': 893,
#  'meets': 894,
#  'sister': 895,
#  'stage': 896,
#  'fantasy': 897,
#  'animals': 898,
#  'became': 899,
#  'previous': 900,
#  'needed': 901,
#  'whatever': 902,
#  'earlier': 903,
#  'stewart': 904,
#  'waiting': 905,
#  'brings': 906,
#  'cute': 907,
#  'agree': 908,
#  'failed': 909,
#  'showing': 910,
#  'result': 911,
#  'effect': 912,
#  'bought': 913,
#  'gay': 914,
#  'badly': 915,
#  'note': 916,
#  'creepy': 917,
#  'fire': 918,
#  'paul': 919,
#  'apart': 920,
#  'move': 921,
#  'mary': 922,
#  'general': 923,
#  'form': 924,
#  'average': 925,
#  'doctor': 926,
#  'co': 927,
#  'pathetic': 928,
#  'admit': 929,
#  'sci': 930,
#  'fi': 931,
#  'feature': 932,
#  'frank': 933,
#  'honestly': 934,
#  'rent': 935,
#  'ask': 936,
#  'greatest': 937,
#  'band': 938,
#  'unless': 939,
#  'crime': 940,
#  'bored': 941,
#  'society': 942,
#  'hands': 943,
#  'beauty': 944,
#  'basic': 945,
#  'kelly': 946,
#  'fighting': 947,
#  'features': 948,
#  'dance': 949,
#  "we're": 950,
#  'filmed': 951,
#  'hardly': 952,
#  '20': 953,
#  'romance': 954,
#  'members': 955,
#  'cartoon': 956,
#  'older': 957,
#  'male': 958,
#  'weak': 959,
#  'copy': 960,
#  'ben': 961,
#  'free': 962,
#  'cop': 963,
#  'science': 964,
#  'certain': 965,
#  'monster': 966,
#  'write': 967,
#  'buy': 968,
#  'expecting': 969,
#  'situation': 970,
#  'surprise': 971,
#  'cat': 972,
#  'team': 973,
#  'consider': 974,
#  'state': 975,
#  'soundtrack': 976,
#  'credits': 977,
#  'actual': 978,
#  'footage': 979,
#  'break': 980,
#  'trash': 981,
#  'joe': 982,
#  'tom': 983,
#  'cheesy': 984,
#  'crazy': 985,
#  'front': 986,
#  'control': 987,
#  'business': 988,
#  'deserves': 989,
#  'decide': 990,
#  'sexual': 991,
#  'dumb': 992,
#  'present': 993,
#  'forward': 994,
#  'zombie': 995,
#  'sees': 996,
#  'joke': 997,
#  'attempts': 998,
#  'recently': 999,
#  '15': 1000,
#  ...}

# %% [markdown]
# ## Using 1D Convolution.
#
# ❓ **Question** ❓ Define a model that has :
# - an `Embedding` layer: `input_dim` is the `vocab_size + 1`, `output_dim` is the embedding space dimension, and `mask_zero` has to be set to `True`. Here, for computational reasons, set `input_length` to the maximum length of your observations (that you just defined in the previous question).
# - a `Conv1D` layer
# - a `Flatten` layer
# - a `Dense` layer
# - an output layer
#
# Compile the model accordingly
#
# ❗ **Remark** ❗ The size of the `Conv1D` kernel corresponds exactly to the number of side-by-side words (tokens) each kernel is taking into account ;)

# %%
from tensorflow.keras import Sequential, layers

def init_cnn_model(vocab_size):
    model = Sequential()
    model.add(layers.Embedding(input_dim=vocab_size+1, output_dim=10, mask_zero=True, input_length=150))
    model.add(layers.Conv1D(16,3))
    model.add(layers.Flatten())
    model.add(layers.Dense(5,))
    model.add(layers.Dense(1, activation='sigmoid'))
    
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

model_cnn = init_cnn_model(vocab_size)

# %% [markdown]
# ❓ **Question** ❓ Look at the number of parameters. You can compare it to the model that you had in previous exercise (esp. the first one)

# %%
model_cnn.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 150, 10)           304200
#
#  conv1d_4 (Conv1D)           (None, 148, 16)           496
#
#  flatten_4 (Flatten)         (None, 2368)              0
#
#  dense_8 (Dense)             (None, 5)                 11845
#
#  dense_9 (Dense)             (None, 1)                 6
#
# =================================================================
# Total params: 316,547
# Trainable params: 316,547
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ❓ **Question** ❓ Fit your model with a stopping criterion, and evaluate it on the test data.
#
# You will probably notice that it is ... **much faster** than RNN.

# %%
from tensorflow.keras.callbacks import EarlyStopping

es = EarlyStopping(patience=5, restore_best_weights=True)

model_cnn.fit(X_train_pad, y_train, 
          epochs=20, 
          batch_size=32,
          validation_split=0.3,
          callbacks=[es]
         )


res = model_cnn.evaluate(X_test_pad, y_test, verbose=0)

print(f'The accuracy evaluated on the test set is of {res[1]*100:.3f}%')
# Out:
# Epoch 1/20
# 55/55 [==============================] - 1s 8ms/step - loss: 0.6921 - accuracy: 0.5234 - val_loss: 0.6875 - val_accuracy: 0.5520
# Epoch 2/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.5949 - accuracy: 0.8486 - val_loss: 0.6641 - val_accuracy: 0.6040
# Epoch 3/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.2782 - accuracy: 0.9651 - val_loss: 0.5652 - val_accuracy: 0.7027
# Epoch 4/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0504 - accuracy: 0.9983 - val_loss: 0.5637 - val_accuracy: 0.7173
# Epoch 5/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0135 - accuracy: 1.0000 - val_loss: 0.5536 - val_accuracy: 0.7320
# Epoch 6/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0063 - accuracy: 1.0000 - val_loss: 0.5611 - val_accuracy: 0.7373
# Epoch 7/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0037 - accuracy: 1.0000 - val_loss: 0.5686 - val_accuracy: 0.7387
# Epoch 8/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0025 - accuracy: 1.0000 - val_loss: 0.5783 - val_accuracy: 0.7387
# Epoch 9/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.5811 - val_accuracy: 0.7427
# Epoch 10/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.5867 - val_accuracy: 0.7467
# The accuracy evaluated on the test set is of 70.800%

# %% [markdown]
# # Part 2 : Learn a Word2Vec representation, and then feed it into a NN with a `Conv1D`🔥
#
# In the first part of the exercise, you were asked to jointly learn the embedding representation and the CNN convolution within the same network, which was the CNN counterpart of the left part of this Figure:
#
# <img src="embedding_or_RNN.png" width="700px" />
#
# Now, let's try to replace the RNN with a CNN for an architecture as on the right side.
#
# ❓ **Question** ❓ Learn a word2vec model or load a trained one directly from GENSIM (transfer learning). Then, prepare your data as in the previous exercise. This question is quite long, it prepares you for real world challenges - but you have already done all the building bricks in the previous exercises

# %%
import gensim.downloader as api
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np

# load a word2vec embedding
word2vec_transfer = api.load("glove-wiki-gigaword-50")

# Function to convert a sentence (list of words) into a matrix representing the words in the embedding space
def embed_sentence_with_TF(word2vec, sentence):
    embedded_sentence = []
    for word in sentence:
        if word in word2vec:
            embedded_sentence.append(word2vec[word])
            
    return np.array(embedded_sentence)

def embedding(word2vec, sentences):
    embed = []
    
    for sentence in sentences:
        embedded_sentence = embed_sentence_with_TF(word2vec, sentence)
        embed.append(embedded_sentence)
        
    return embed

# Embed the training and test sentences
X_train_embed_2 = embedding(word2vec_transfer, X_train)
X_test_embed_2 = embedding(word2vec_transfer, X_test)

# Pad the training and test embedded sentences
X_train_pad_2 = pad_sequences(X_train_embed_2, maxlen=150, padding='post', dtype='float32')
X_test_pad_2 = pad_sequences(X_test_embed_2, maxlen=150, padding='post', dtype='float32')

# %% [markdown]
# ❓ **Question** ❓ Now construct a model that has a `Conv1D` layer, a flatten layer, a dense layer, and an output layer. Compile it, and fit it on the train data. You can then evaluate it on the test set.

# %%
def init_cnn_model_2():
    model = Sequential()
    model.add(layers.Conv1D(16, 3))
    model.add(layers.Flatten())
    model.add(layers.Dense(5,))
    model.add(layers.Dense(1, activation='sigmoid'))

    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

model_cnn_2 = init_cnn_model_2()

# %%
es_2 = EarlyStopping(patience=5, restore_best_weights=True)

model_cnn_2.fit(X_train_pad_2, y_train, 
          epochs=20, 
          batch_size=32,
          validation_split=0.3,
          callbacks=[es_2]
         )


res = model_cnn_2.evaluate(X_test_pad_2, y_test, verbose=0)

print(f'The accuracy evaluated on the test set is of {res[1]*100:.3f}%')
# Out:
# Epoch 1/20
# 55/55 [==============================] - 1s 9ms/step - loss: 0.8537 - accuracy: 0.5463 - val_loss: 0.7053 - val_accuracy: 0.5880
# Epoch 2/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.5686 - accuracy: 0.7023 - val_loss: 0.6516 - val_accuracy: 0.6533
# Epoch 3/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.4422 - accuracy: 0.7994 - val_loss: 0.6495 - val_accuracy: 0.6733
# Epoch 4/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.3598 - accuracy: 0.8531 - val_loss: 0.6621 - val_accuracy: 0.6747
# Epoch 5/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.2898 - accuracy: 0.8966 - val_loss: 0.6883 - val_accuracy: 0.6733
# Epoch 6/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.2412 - accuracy: 0.9206 - val_loss: 0.7410 - val_accuracy: 0.6720
# Epoch 7/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.1865 - accuracy: 0.9537 - val_loss: 0.7951 - val_accuracy: 0.6760
# Epoch 8/20
# 55/55 [==============================] - 0s 5ms/step - loss: 0.1463 - accuracy: 0.9766 - val_loss: 0.8659 - val_accuracy: 0.6680
# The accuracy evaluated on the test set is of 63.200%

# %% [markdown]
# ❓ **Question** ❓ You might be frustrated by the accuracy you got, this happens to us all at some point. Once you have tested your first iteration, you need to improve your models: by making them more complex, changing the parameters, stacking additional layers, and so on.
#
# Only practice and experimentation will get you there. So you can go back to your previous models, change them and try to get better results ;)
